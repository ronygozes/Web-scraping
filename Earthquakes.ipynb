# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-4.0.0-py3-none-any.whl (954 kB)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\marin\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Collecting trio~=0.17
#   Using cached trio-0.19.0-py3-none-any.whl (356 kB)
# Collecting trio-websocket~=0.9
#   Using cached trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: async-generator>=1.9 in c:\users\marin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\marin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\marin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.5)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\marin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (20.3.0)
# Requirement already satisfied: sniffio in c:\users\marin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\marin\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.3.0)
# Collecting outcome
#   Using cached outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: pycparser in c:\users\marin\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Using cached wsproto-1.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\marin\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (20.0.1)
# Requirement already satisfied: certifi in c:\users\marin\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2020.12.5)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\marin\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.7)
# Requirement already satisfied: six>=1.5.2 in c:\users\marin\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.15.0)
# Collecting h11<1,>=0.9.0
#   Using cached h11-0.12.0-py3-none-any.whl (54 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.12.0 outcome-1.1.0 selenium-4.0.0 trio-0.19.0 trio-websocket-0.9.2 wsproto-1.0.0

# %%
#Import relevant packages

from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup
import pandas as pd 
import re

# %%
#url to live updates from last 24 hours on earthquakes with magnitude above 2.5
MAIN_URL = "https://earthquake.usgs.gov/earthquakes/map"

# %%
def get_urls_from_main_page(MAIN_URL):
    """ The function receives as parameter url to webpage of earthquake updates and
    return list of urls to individual events
    """
    #Setting webdriver to Chrome
    driver = webdriver.Chrome()
    
    driver.get(MAIN_URL)
    elements = driver.find_elements(By.TAG_NAME, 'mat-list-item')
    driver.execute_script('arguments[0].click()', elements[0])
    sleep(3)

    urls = []

    for i in range(1, len(elements)):
        driver.execute_script('arguments[0].click()', elements[i])
        sleep(0.2)
        link = driver.find_elements(By.TAG_NAME, 'a')[-1]
        # to exclude hyperlinks not related to earthquake event  (like tsunami gov)
        if 'eventpage' in link.get_attribute('href'):
            urls.append(link.get_attribute('href'))
    print(urls)
    return urls

# %%
#Testing function above
urls =  get_urls_from_main_page(MAIN_URL)
# Out:
# ['https://earthquake.usgs.gov/earthquakes/eventpage/ak021e0ky9z3/pager', 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72777902/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqgj/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72777822/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqgf/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqgd/', 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72777717/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqfv/', 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2021305002/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqf0/pager', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqez/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqew/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqet/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqeh/shakemap', 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2021305000/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqea/', 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72777407/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqdi/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqcg/pager', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqcf/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqca/', 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72777277/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqby/', 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021dz41vmb/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqbt/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqbj/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqbe/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqax/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqac/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqab/', 'https://earthquake.usgs.gov/earthquakes/eventpage/hv72776767/dyfi', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqa4/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9w/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9x/', 'https://earthquake.usgs.gov/earthquakes/eventpage/ak021dyysd0v/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9s/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/', 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/']

# %%
def get_detail_url(urls):
    """ preparing urls with relevant information for "details page"
    parameters: list of urls
    returns: updated list of urls for individual page
    """
    new_url_list=[]
    for url in urls:
        if  url[-1] == '/':
            url = url + 'origin/detail'
            new_url_list.append(url)
            
        else:
            url = re.sub(r'/(\w*)$', '/origin/detail', url)
            new_url_list.append(url)
            
    detail_urls = list(set(new_url_list))
    return detail_urls

# %%
def get_event_details(detail_urls):
    """
    The function receives list of urls providing details for specific earthquakes. 
    After extraction relevant information it returns a dataframe table 
    where each row provides information on individual earthquake.
    """
    list_events = []
    for url in detail_urls:
        driver.get(url)
        sleep(2.5)
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')

        #Extracting into list data categories
        clean_elem=[]
        clean_elem.append('url') #first element will be url itself
        elements = soup.find_all("dt")
        for element in elements:
            element = element.text.strip()
            if 'uncertainty'in element:
                element1 = element[:element.index("uncertainty")]
                clean_elem.append(element1)
                element2 = element1 + ' uncertainty'
                clean_elem.append(element2)
            else:
                clean_elem.append(element) 


        #Extracting into list data itself
        clean_data=[] 
        clean_data.append(url) #first element will be url itself
        data = soup.find_all("dd")
        for info in data:
            info = info.text.strip()
            if '±' in info:
                info1 = info[:info.index('±')].strip()
                clean_data.append(info1)
                info_uncert = info[info.index('±'):].strip()
                clean_data.append(info_uncert)
            else:
                clean_data.append(info)

        #Pairing categories with data itself
        data_extract = dict(list(zip(clean_elem, clean_data)))
        list_events.append(data_extract)
        print(f'Status: events from url {url} added to dict')
     
        
    return pd.DataFrame(list_events)

# %%
#Testing two functions:

detail_urls = get_detail_url(urls)
event_table=get_event_details(detail_urls)
print(event_table.head(10))
# Out:
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/pr2021305000/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/ak021e0ky9z3/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/hv72777902/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqgj/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9q/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqew/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqcg/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqf0/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqgd/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqet/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqbj/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/hv72777717/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqfv/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqa4/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqez/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9s/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/hv72777822/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqac/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqcf/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqby/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqdi/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9w/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/hv72777277/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/hv72776767/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqeh/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/hv72777407/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fq9x/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqab/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqax/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/ak021dz41vmb/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqbe/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/ak021dyysd0v/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqea/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/pr2021305002/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqbt/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqgf/origin/detail added to dict
# events from url https://earthquake.usgs.gov/earthquakes/eventpage/us7000fqca/origin/detail added to dict
#                                                  url Magnitude  \
# 0  https://earthquake.usgs.gov/earthquakes/eventp...   2.57 md
# 1  https://earthquake.usgs.gov/earthquakes/eventp...    3.8 ml
# 2  https://earthquake.usgs.gov/earthquakes/eventp...   2.54 ml
# 3  https://earthquake.usgs.gov/earthquakes/eventp...    4.4 mb
# 4  https://earthquake.usgs.gov/earthquakes/eventp...    4.5 mb
# 5  https://earthquake.usgs.gov/earthquakes/eventp...    4.8 mb
# 6  https://earthquake.usgs.gov/earthquakes/eventp...   6.1 mww
# 7  https://earthquake.usgs.gov/earthquakes/eventp...    4.5 mb
# 8  https://earthquake.usgs.gov/earthquakes/eventp...    4.4 mb
# 9  https://earthquake.usgs.gov/earthquakes/eventp...    4.7 mb
#
#   Magnitude uncertainty              Location Location uncertainty    Depth  \
# 0                 ± 0.2   17.977°N \n66.818°W             ± 0.4 km  15.0 km
# 1                   NaN  55.505°N \n155.793°W                  NaN  15.0 km
# 2                 ± 3.5  19.168°N \n155.455°W             ± 0.5 km  31.4 km
# 3                 ± 0.0   12.878°N \n88.720°W             ± 5.8 km  65.7 km
# 4                 ± 0.1  54.939°N \n165.769°E             ± 4.1 km  38.0 km
# 5                 ± 0.1  22.935°S \n174.500°W             ± 5.6 km  10.0 km
# 6                 ± 0.1   58.047°S \n25.316°W             ± 9.4 km  35.0 km
# 7                 ± 0.2  36.731°N \n104.996°W             ± 2.7 km   6.2 km
# 8                 ± 0.1   4.433°S \n102.021°E             ± 7.0 km  35.0 km
# 9                 ± 0.1   58.071°S \n25.239°W            ± 13.4 km  35.0 km
#
#   Depth uncertainty                  Origin Time Number of Stations  \
# 0             ± 0.4  2021-11-01 01:35:35.680 UTC                 16
# 1             ± 2.0  2021-11-01 10:14:43.650 UTC                  -
# 2             ± 0.6  2021-11-01 08:15:47.750 UTC                 51
# 3             ± 7.9  2021-11-01 07:37:42.435 UTC                  -
# 4             ± 7.0  2021-10-31 12:18:06.225 UTC                  -
# 5             ± 1.9  2021-11-01 02:53:34.713 UTC                  -
# 6             ± 1.9  2021-11-01 00:02:51.155 UTC                  -
# 7             ± 3.6  2021-11-01 03:09:15.531 UTC                  -
# 8             ± 2.0  2021-11-01 06:19:38.253 UTC                  -
# 9             ± 2.0  2021-11-01 02:50:59.175 UTC                  -
#
#   Number of Phases    Minimum Distance Travel Time Residual Azimuthal Gap  \
# 0               32   24.7 km ( 0.22° )               0.11 s          178°
# 1               31             - ( - )               0.58 s             -
# 2               73             - ( - )        0.119999997 s          139°
# 3              214   95.3 km ( 0.86° )               0.47 s          111°
# 4               72  514.2 km ( 4.62° )                0.5 s          103°
# 5               21  780.3 km ( 7.01° )               0.79 s          113°
# 6               56  811.1 km ( 7.29° )               0.88 s           57°
# 7               32   12.7 km ( 0.11° )               0.43 s           66°
# 8               60  104.1 km ( 0.94° )               0.49 s          119°
# 9               21  816.4 km ( 7.33° )               0.75 s          168°
#
#                                   FE Region Review Status  \
# 0                   Puerto Rico region (90)      REVIEWED
# 1                      south of Alaska (17)      REVIEWED
# 2               Island of Hawaii, Hawaii ()     AUTOMATIC
# 3     off the coast of Central America (76)      REVIEWED
# 4  Komandorskiye Ostrova, Russia region (4)      REVIEWED
# 5                        Tonga region (174)      REVIEWED
# 6       South Sandwich Islands region (153)      REVIEWED
# 7                          New Mexico (496)      REVIEWED
# 8         southern Sumatra, Indonesia (274)      REVIEWED
# 9       South Sandwich Islands region (153)      REVIEWED
#
#                 Catalog Location Source Magnitude Source Contributor
# 0  PR  ( pr2021305000 )           PR  1            PR  1       PR  1
# 1  AK  ( ak021e0ky9z3 )           AK  1            AK  1       AK  1
# 2    HV  ( hv72777902 )           HV  1            HV  1       HV  1
# 3    US  ( us7000fqgj )           US  1            US  1       US  1
# 4    US  ( us7000fq9q )           US  1            US  1       US  1
# 5    US  ( us7000fqew )           US  1            US  1       US  1
# 6    US  ( us7000fqcg )           US  1            US  1       US  1
# 7    US  ( us7000fqf0 )           US  1            US  1       US  1
# 8    US  ( us7000fqgd )           US  1            US  1       US  1
# 9    US  ( us7000fqet )           US  1            US  1       US  1

# %%
#Put in main function

df.to_csv('earthquakes.csv', index=False, encoding="utf-8-sig")
